# %% [markdown]
# # The Product Pricer Continued
#
# A model that can estimate how much something costs, from its description.
#
# ## AT LAST - it's time for Fine Tuning!
#
# After all this data preparation, and old school machine learning, we've finally arrived at the moment you've been waiting for. Fine-tuning a model.

# %%
# imports

import os
import re
import math
import json
import random
from dotenv import load_dotenv
from huggingface_hub import login
import matplotlib.pyplot as plt
import numpy as np
import pickle
from collections import Counter
from openai import OpenAI
from anthropic import Anthropic

# %%
# environment

load_dotenv(override=True)
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['ANTHROPIC_API_KEY'] = os.getenv('ANTHROPIC_API_KEY', 'your-key-if-not-using-env')
os.environ['HF_TOKEN'] = os.getenv('HF_TOKEN', 'your-key-if-not-using-env')

# %%
# Log in to HuggingFace

hf_token = os.environ['HF_TOKEN']
login(hf_token, add_to_git_credential=True)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# moved our Tester into a separate package
# call it with Tester.test(function_name, test_dataset)

from items import Item
from testing import Tester

# %%
openai = OpenAI()

# %%
# %matplotlib inline

# %%
# Let's avoid curating all our data again! Load in the pickle files:

with open('train.pkl', 'rb') as file:
    train = pickle.load(file)

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
# OpenAI recommends fine-tuning with populations of 50-100 examples
# But as our examples are very small, I'm suggesting we go with 200 examples (and 1 epoch)

fine_tune_train = train[:200]
fine_tune_validation = train[200:250]

# %% [markdown]
# # Step 1
#
# Prepare our data for fine-tuning in JSONL (JSON Lines) format and upload to OpenAI

# %%
# First let's work on a good prompt for a Frontier model
# Notice that I'm removing the " to the nearest dollar"
# When we train our own models, we'll need to make the problem as easy as possible, 
# but a Frontier model needs no such simplification.

def messages_for(item):
    system_message = "You estimate prices of items. Reply only with the price, no explanation"
    user_prompt = item.test_prompt().replace(" to the nearest dollar","").replace("\n\nPrice is $","")
    return [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_prompt},
        {"role": "assistant", "content": f"Price is ${item.price:.2f}"}
    ]

# %%
messages_for(train[0])
# Out:
# [{'role': 'system',
#   'content': 'You estimate prices of items. Reply only with the price, no explanation'},
#  {'role': 'user',
#   'content': 'How much does this cost?\n\nDelphi FG0166 Fuel Pump Module\nDelphi brings 80 years of OE Heritage into each Delphi pump, ensuring quality and fitment for each Delphi part. Part is validated, tested and matched to the right vehicle application Delphi brings 80 years of OE Heritage into each Delphi assembly, ensuring quality and fitment for each Delphi part Always be sure to check and clean fuel tank to avoid unnecessary returns Rigorous OE-testing ensures the pump can withstand extreme temperatures Brand Delphi, Fit Type Vehicle Specific Fit, Dimensions LxWxH 19.7 x 7.7 x 5.1 inches, Weight 2.2 Pounds, Auto Part Position Unknown, Operation Mode Mechanical, Manufacturer Delphi, Model FUEL PUMP, Dimensions 19.7'},
#  {'role': 'assistant', 'content': 'Price is $226.95'}]

# %%
# Convert the items into a list of json objects - a "jsonl" string
# Each row represents a message in the form:
# {"messages" : [{"role": "system", "content": "You estimate prices...


def make_jsonl(items):
    result = ""
    for item in items:
        messages = messages_for(item)
        messages_str = json.dumps(messages)
        result += '{"messages": ' + messages_str +'}\n'
    return result.strip()

# %%
print(make_jsonl(train[:3]))
# Out:
# {"messages": [{"role": "system", "content": "You estimate prices of items. Reply only with the price, no explanation"}, {"role": "user", "content": "How much does this cost?\n\nDelphi FG0166 Fuel Pump Module\nDelphi brings 80 years of OE Heritage into each Delphi pump, ensuring quality and fitment for each Delphi part. Part is validated, tested and matched to the right vehicle application Delphi brings 80 years of OE Heritage into each Delphi assembly, ensuring quality and fitment for each Delphi part Always be sure to check and clean fuel tank to avoid unnecessary returns Rigorous OE-testing ensures the pump can withstand extreme temperatures Brand Delphi, Fit Type Vehicle Specific Fit, Dimensions LxWxH 19.7 x 7.7 x 5.1 inches, Weight 2.2 Pounds, Auto Part Position Unknown, Operation Mode Mechanical, Manufacturer Delphi, Model FUEL PUMP, Dimensions 19.7"}, {"role": "assistant", "content": "Price is $226.95"}]}
# {"messages": [{"role": "system", "content": "You estimate prices of items. Reply only with the price, no explanation"}, {"role": "user", "content": "How much does this cost?\n\nPower Stop Rear Z36 Truck and Tow Brake Kit with Calipers\nThe Power Stop Z36 Truck & Tow Performance brake kit provides the superior stopping power demanded by those who tow boats, haul loads, tackle mountains, lift trucks, and play in the harshest conditions. The brake rotors are drilled to keep temperatures down during extreme braking and slotted to sweep away any debris for constant pad contact. Combined with our Z36 Carbon-Fiber Ceramic performance friction formulation, you can confidently push your rig to the limit and look good doing it with red powder brake calipers. Components are engineered to handle the stress of towing, hauling, mountainous driving, and lifted trucks. Dust-free braking performance. Z36 Carbon-Fiber Ceramic formula provides the extreme braking performance demanded by your truck or 4x"}, {"role": "assistant", "content": "Price is $506.98"}]}
# {"messages": [{"role": "system", "content": "You estimate prices of items. Reply only with the price, no explanation"}, {"role": "user", "content": "How much does this cost?\n\nABBA 36 Gas Cooktop with 5 Sealed Burners - Tempered Glass Surface with SABAF Burners, Natural Gas Stove for Countertop, Home Improvement Essentials, Easy to Clean, 36 x 4.1 x 20.5\ncooktop Gas powered with 4 fast burners and 1 ultra-fast center burner Tempered glass surface with removable grid for easy cleaning Lightweight for easy installation. Installation Manual Included Counter cutout Dimensions 19 3/8 x 34 1/2 (see diagram) Insured shipping for your satisfaction and peace of mind Brand Name ABBA EST. 1956, Weight 30 pounds, Dimensions 20.5\\ D x 36\\ W x 4.1\\ H, Installation Type Count"}, {"role": "assistant", "content": "Price is $405.00"}]}

# %%
# Convert the items into jsonl and write them to a file

def write_jsonl(items, filename):
    with open(filename, "w") as f:
        jsonl = make_jsonl(items)
        f.write(jsonl)

# %%
write_jsonl(fine_tune_train, "fine_tune_train.jsonl")

# %%
write_jsonl(fine_tune_validation, "fine_tune_validation.jsonl")

# %%
# We need it to upload the fine-tune training data to OpenAI
# Open the file in binary mode because is the way it will be streamed to openai
with open("fine_tune_train.jsonl", "rb") as f:
    train_file = openai.files.create(file=f, purpose="fine-tune")

# %%
train_file
# Out:
# FileObject(id='file-81DKbdFu6VACyfvUENWqDz', bytes=187905, created_at=1749238537, filename='fine_tune_train.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %%
with open("fine_tune_validation.jsonl", "rb") as f:
    validation_file = openai.files.create(file=f, purpose="fine-tune")

# %%
validation_file
# Out:
# FileObject(id='file-L3yq9Qtph4qjpNZ19W8bnp', bytes=47779, created_at=1749238824, filename='fine_tune_validation.jsonl', object='file', purpose='fine-tune', status='processed', expires_at=None, status_details=None)

# %% [markdown]
# # Step 2
#
# I love Weights and Biases - a beautiful, free platform for monitoring training runs.
# Weights and Biases is integrated with OpenAI for fine-tuning.
#
# First set up your weights & biases free account at:
#
# https://wandb.ai
#
# From the Avatar >> Settings menu, near the bottom, you can create an API key.
#
# Then visit the OpenAI dashboard at:
#
# https://platform.openai.com/account/organization
#
# In the integrations section, you can add your Weights & Biases key.
#
# ## And now time to Fine-tune!

# %%
wandb_integration = {"type": "wandb", "wandb": {"project": "gpt-pricer"}}

# %%
train_file.id
# Out:
# 'file-81DKbdFu6VACyfvUENWqDz'

# %%
openai.fine_tuning.jobs.create(
    training_file=train_file.id,
    validation_file=validation_file.id,
    model="gpt-4o-mini-2024-07-18",
    seed=42,
    hyperparameters={"n_epochs": 1},
    integrations = [wandb_integration],
    suffix="pricer"
)
# Out:
# FineTuningJob(id='ftjob-b1wqFoC2X7pVVixdDyIoCiip', created_at=1749239624, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs=1), model='gpt-4o-mini-2024-07-18', object='fine_tuning.job', organization_id='org-mNVSx55KwvoKhzyhQKRNKuoO', result_files=[], seed=42, status='validating_files', trained_tokens=None, training_file='file-81DKbdFu6VACyfvUENWqDz', validation_file='file-L3yq9Qtph4qjpNZ19W8bnp', estimated_finish=None, integrations=[FineTuningJobWandbIntegrationObject(type='wandb', wandb=FineTuningJobWandbIntegration(project='gpt-pricer', entity=None, name=None, tags=None, run_id='ftjob-b1wqFoC2X7pVVixdDyIoCiip'))], metadata=None, method=Method(dpo=None, supervised=MethodSupervised(hyperparameters=MethodSupervisedHyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs=1)), type='supervised'), user_provided_suffix='pricer', usage_metrics=None, shared_with_openai=False, eval_id=None)

# %%
openai.fine_tuning.jobs.list(limit=1)
# Out:
# SyncCursorPage[FineTuningJob](data=[FineTuningJob(id='ftjob-b1wqFoC2X7pVVixdDyIoCiip', created_at=1749239624, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs=1), model='gpt-4o-mini-2024-07-18', object='fine_tuning.job', organization_id='org-mNVSx55KwvoKhzyhQKRNKuoO', result_files=[], seed=42, status='validating_files', trained_tokens=None, training_file='file-81DKbdFu6VACyfvUENWqDz', validation_file='file-L3yq9Qtph4qjpNZ19W8bnp', estimated_finish=None, integrations=[FineTuningJobWandbIntegrationObject(type='wandb', wandb=FineTuningJobWandbIntegration(project='gpt-pricer', entity=None, name=None, tags=None, run_id='ftjob-b1wqFoC2X7pVVixdDyIoCiip'))], metadata=None, method=Method(dpo=None, supervised=MethodSupervised(hyperparameters=MethodSupervisedHyperparameters(batch_size='auto', learning_rate_multiplier='auto', n_epochs=1)), type='supervised'), user_provided_suffix='pricer', usage_metrics=None, shared_with_openai=False, eval_id=None)], has_more=False, object='list')

# %%
job_id = openai.fine_tuning.jobs.list(limit=1).data[0].id

# %%
job_id
# Out:
# 'ftjob-b1wqFoC2X7pVVixdDyIoCiip'

# %%
openai.fine_tuning.jobs.retrieve(job_id)
# Out:
# FineTuningJob(id='ftjob-b1wqFoC2X7pVVixdDyIoCiip', created_at=1749239624, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(batch_size=1, learning_rate_multiplier=1.8, n_epochs=1), model='gpt-4o-mini-2024-07-18', object='fine_tuning.job', organization_id='org-mNVSx55KwvoKhzyhQKRNKuoO', result_files=[], seed=42, status='running', trained_tokens=None, training_file='file-81DKbdFu6VACyfvUENWqDz', validation_file='file-L3yq9Qtph4qjpNZ19W8bnp', estimated_finish=None, integrations=[FineTuningJobWandbIntegrationObject(type='wandb', wandb=FineTuningJobWandbIntegration(project='gpt-pricer', entity=None, name=None, tags=None, run_id='ftjob-b1wqFoC2X7pVVixdDyIoCiip'))], metadata=None, method=Method(dpo=None, supervised=MethodSupervised(hyperparameters=MethodSupervisedHyperparameters(batch_size=1, learning_rate_multiplier=1.8, n_epochs=1)), type='supervised'), user_provided_suffix='pricer', usage_metrics=None, shared_with_openai=False, eval_id=None)

# %%
openai.fine_tuning.jobs.list_events(fine_tuning_job_id=job_id, limit=10).data
# Out:
# [FineTuningJobEvent(id='ftevent-uOtXdEZxaZhlULTjehMlySe7', created_at=1749239728, level='info', message='Fine-tuning job started', object='fine_tuning.job.event', data=None, type='message'),
#  FineTuningJobEvent(id='ftevent-zMSgoicPIXClxBokh6IW58TL', created_at=1749239726, level='info', message='Files validated, moving job to queued state', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-wEsNMqVnOgwf0o83iFmGBbYo', created_at=1749239624, level='info', message='Validating training file: file-81DKbdFu6VACyfvUENWqDz and validation file: file-L3yq9Qtph4qjpNZ19W8bnp', object='fine_tuning.job.event', data={}, type='message'),
#  FineTuningJobEvent(id='ftevent-hwHom3NUrqYzuIwNIubsGUrc', created_at=1749239624, level='info', message='Created fine-tuning job: ftjob-b1wqFoC2X7pVVixdDyIoCiip', object='fine_tuning.job.event', data={}, type='message')]

# %% [markdown]
# # Step 3
#
# Test our fine tuned model

# %%
fine_tuned_model_name = openai.fine_tuning.jobs.retrieve(job_id).fine_tuned_model

# %%
fine_tuned_model_name
# Out:
# 'ft:gpt-4o-mini-2024-07-18:personal:pricer:BfXZUnip'

# %%
# The prompt

def messages_for(item):
    system_message = "You estimate prices of items. Reply only with the price, no explanation"
    user_prompt = item.test_prompt().replace(" to the nearest dollar","").replace("\n\nPrice is $","")
    return [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_prompt},
        {"role": "assistant", "content": "Price is $"}
    ]

# %%
# Try this out

messages_for(test[0])
# Out:
# [{'role': 'system',
#   'content': 'You estimate prices of items. Reply only with the price, no explanation'},
#  {'role': 'user',
#   'content': "How much does this cost?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K"},
#  {'role': 'assistant', 'content': 'Price is $'}]

# %%
# A utility function to extract the price from a string

def get_price(s):
    s = s.replace('$','').replace(',','')
    match = re.search(r"[-+]?\d*\.\d+|\d+", s)
    return float(match.group()) if match else 0

# %%
get_price("The price is roughly $99.99 because blah blah")
# Out:
# 99.99

# %%
# The function for gpt-4o-mini

def gpt_fine_tuned(item):
    response = openai.chat.completions.create(
        model=fine_tuned_model_name, 
        messages=messages_for(item),
        seed=42,
        max_tokens=7
    )
    reply = response.choices[0].message.content
    return get_price(reply)

# %%
print(test[0].price)
print(gpt_fine_tuned(test[0]))
# Out:
# 374.41
# 490.0

# %%
print(test[0].test_prompt())
# Out:
# How much does this cost to the nearest dollar?
#
# OEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW
# As one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K
#
# Price is $

# %%
Tester.test(gpt_fine_tuned, test)
# Out:
# 1: Guess: $490.00 Truth: $374.41 Error: $115.59 SLE: 0.07 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $127.22 Truth: $225.00 Error: $97.78 SLE: 0.32 Item: Microsoft Surface 3 7G6-00001 10.8 Inch ...
# 3: Guess: $47.22 Truth: $61.73 Error: $14.51 SLE: 0.07 Item: Dorman 741-714 Front Passenger Side Powe...
# 4: Guess: $277.65 Truth: $599.99 Error: $322.34 SLE: 0.59 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $22.99 Truth: $16.97 Error: $6.02 SLE: 0.08 Item: The Best Card Company - 20 Bulk Animal N...
# 6: Guess: $47.99 Truth: $31.99 Error: $16.00 SLE: 0.16 Item: ITSHINY Waterproof Laptop Travel Backpac...
# 7: Guess: $22.22 Truth: $101.55 Error: $79.33 SLE: 2.21 Item: Uniweld MTF-9 Cap'n Hook 9 Flame Tip sil...
# 8: Guess: $262.47 Truth: $289.00 Error: $26.53 SLE: 0.01 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $499.99 Truth: $635.86 Error: $135.87 SLE: 0.06 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# 10: Guess: $47.95 Truth: $66.00 Error: $18.05 SLE: 0.10 Item: Uncle Goose Greek Mythology Blocks - Mad...
# 11: Guess: $174.99 Truth: $254.21 Error: $79.22 SLE: 0.14 Item: Viking Horns V103C/1005ATK 3 Gallon Air ...
# 12: Guess: $322.22 Truth: $412.99 Error: $90.77 SLE: 0.06 Item: CURT 70110 Custom Tow Bar Base Plate Bra...
# 13: Guess: $49.77 Truth: $205.50 Error: $155.73 SLE: 1.97 Item: 10-Pack Solar HAMMERED BRONZE Finish Pos...
# 14: Guess: $319.99 Truth: $248.23 Error: $71.76 SLE: 0.06 Item: COSTWAY Electric Tumble Dryer, Sliver
# 15: Guess: $219.00 Truth: $399.00 Error: $180.00 SLE: 0.36 Item: FREE SIGNAL TV Transit 32" 12 Volt DC Po...
# 16: Guess: $322.22 Truth: $373.94 Error: $51.72 SLE: 0.02 Item: Bilstein 5100 Monotube Gas Shock Set com...
# 17: Guess: $47.22 Truth: $93.42 Error: $46.20 SLE: 0.45 Item: Festool 494391 Hold Down Clamp
# 18: Guess: $174.99 Truth: $51.59 Error: $123.40 SLE: 1.46 Item: Classy Caps HL152 Eclipse Solar Hanging ...
# 19: Guess: $47.22 Truth: $179.00 Error: $131.78 SLE: 1.73 Item: Star Wars Starfighter Vehicle Hailfire D...
# 20: Guess: $66.47 Truth: $18.99 Error: $47.48 SLE: 1.48 Item: (1-Pack) 4Benefit Compatible CLT-407S To...
# 21: Guess: $559.47 Truth: $539.95 Error: $19.52 SLE: 0.00 Item: ROKINON 85mm F1.4 Auto Focus Full Frame ...
# 22: Guess: $83.00 Truth: $147.95 Error: $64.95 SLE: 0.33 Item: Global Honing Rod G-38/B, 10in/26cm Knif...
# 23: Guess: $127.22 Truth: $24.99 Error: $102.23 SLE: 2.55 Item: Librasun Jason Voorhees Action Figure Fr...
# 24: Guess: $127.22 Truth: $148.51 Error: $21.29 SLE: 0.02 Item: Lexmark 14N1807 150XL Color Tri Pk
# 25: Guess: $47.95 Truth: $16.99 Error: $30.96 SLE: 1.00 Item: XSKN Magic Keyboard Premiere Pro Shortcu...
# 26: Guess: $22.69 Truth: $7.99 Error: $14.70 SLE: 0.94 Item: IKN LP Style Pickguard 3Ply Black with B...
# 27: Guess: $249.99 Truth: $199.99 Error: $50.00 SLE: 0.05 Item: Samson DK705 5-Piece Drum Microphone Kit...
# 28: Guess: $127.99 Truth: $251.45 Error: $123.46 SLE: 0.45 Item: Apple Watch Series 6 (GPS, 44mm) - Space...
# 29: Guess: $276.10 Truth: $231.62 Error: $44.48 SLE: 0.03 Item: ICON 01725 Tandem Axle Fender Skirt FS17...
# 30: Guess: $47.95 Truth: $135.00 Error: $87.05 SLE: 1.04 Item: TEMCo TH0359 - New TEMCo Double D Punch ...
# 31: Guess: $47.22 Truth: $356.62 Error: $309.40 SLE: 4.01 Item: Velvac 2020,L,C/Hr,W,E2003,102",Bk - 715...
# 32: Guess: $127.99 Truth: $257.99 Error: $130.00 SLE: 0.49 Item: TCMT Passenger Backrest Sissy Bar & Lugg...
# 33: Guess: $34.98 Truth: $27.99 Error: $6.99 SLE: 0.05 Item: KipiPol Make Your Own Water Globe Kit – ...
# 34: Guess: $127.22 Truth: $171.20 Error: $43.98 SLE: 0.09 Item: Subaru Forester Outback Legacy OEM Engin...
# 35: Guess: $154.65 Truth: $225.14 Error: $70.49 SLE: 0.14 Item: Heidenau K60 Scout Rear 130/80-17 Motorc...
# 36: Guess: $47.22 Truth: $105.00 Error: $57.78 SLE: 0.62 Item: ORE International 6129IV 32-Inch Metal L...
# 37: Guess: $219.98 Truth: $299.99 Error: $80.01 SLE: 0.10 Item: Road Top Wireless Carplay Retrofit Kit D...
# 38: Guess: $571.22 Truth: $535.09 Error: $36.13 SLE: 0.00 Item: Gibson Performance Exhaust 5658 Aluminiz...
# 39: Guess: $32.99 Truth: $11.95 Error: $21.04 SLE: 0.93 Item: GIFTS INFINITY® Personalized Laser Engra...
# 40: Guess: $139.98 Truth: $85.12 Error: $54.86 SLE: 0.24 Item: Rockin' Rider Laurel Rocking Horse, Pink...
# 41: Guess: $30.47 Truth: $15.95 Error: $14.52 SLE: 0.38 Item: Emily Rose 18-inch Doll Ballerina 4 PC B...
# 42: Guess: $110.47 Truth: $62.10 Error: $48.37 SLE: 0.32 Item: MiLocks TFK-02SN Digital Deadbolt Door L...
# 43: Guess: $139.98 Truth: $82.99 Error: $56.99 SLE: 0.27 Item: Tangkula 3 Lights Floor Lamp, Retro Floo...
# 44: Guess: $174.00 Truth: $599.95 Error: $425.95 SLE: 1.52 Item: Sony SSCS8 2-Way 3-Driver Center Channel...
# 45: Guess: $262.47 Truth: $195.00 Error: $67.47 SLE: 0.09 Item: Samsung Galaxy A30S A307G 64GB Unlocked ...
# 46: Guess: $249.99 Truth: $344.95 Error: $94.96 SLE: 0.10 Item: FiiO X7 32GB Hi-Res Lossless Music Playe...
# 47: Guess: $65.98 Truth: $38.14 Error: $27.84 SLE: 0.29 Item: Keenso Dollhouse Kitchen Furniture, 112 ...
# 48: Guess: $490.00 Truth: $224.35 Error: $265.65 SLE: 0.61 Item: Universal Air Conditioner KT 1031 A/C Co...
# 49: Guess: $572.47 Truth: $814.00 Error: $241.53 SLE: 0.12 Item: Street Series Stainless Performance Cat-...
# 50: Guess: $393.69 Truth: $439.88 Error: $46.19 SLE: 0.01 Item: Lenovo IdeaPad 3 14-inch Laptop, 14.0-in...
# 51: Guess: $594.00 Truth: $341.43 Error: $252.57 SLE: 0.31 Item: Access Bed Covers TonnoSport 22050219 - ...
# 52: Guess: $127.22 Truth: $47.43 Error: $79.79 SLE: 0.95 Item: Dorman 740-151 Front Passenger Side Wind...
# 53: Guess: $262.47 Truth: $171.44 Error: $91.03 SLE: 0.18 Item: T&S Brass B-0232-BST Double Pantry Fauce...
# 54: Guess: $47.22 Truth: $458.00 Error: $410.78 SLE: 5.08 Item: ZTUOAUMA Fuel Injection Pump 3090942 309...
# 55: Guess: $47.22 Truth: $131.25 Error: $84.03 SLE: 1.02 Item: Tiffany Style Ceiling Fixture Lamp Missi...
# 56: Guess: $83.49 Truth: $83.95 Error: $0.46 SLE: 0.00 Item: LUXPaper 9 x 12 Open End Window Envelope...
# 57: Guess: $47.22 Truth: $386.39 Error: $339.17 SLE: 4.34 Item: Jeep Genuine Accessories 82213051 Hood L...
# 58: Guess: $127.22 Truth: $169.00 Error: $41.78 SLE: 0.08 Item: DELTA FAUCET 52488-BL Delta H2Okinetic 4...
# 59: Guess: $47.99 Truth: $18.05 Error: $29.94 SLE: 0.89 Item: SAMSUNG Galaxy S20+ Plus Case, Kvadrat B...
# 60: Guess: $127.99 Truth: $269.00 Error: $141.01 SLE: 0.55 Item: Snailfly Black Roof Rack Rail + Cross Ba...
# 61: Guess: $128.66 Truth: $77.94 Error: $50.72 SLE: 0.25 Item: Accumulair Platinum 24x28x1 (Actual Size...
# 62: Guess: $219.00 Truth: $89.00 Error: $130.00 SLE: 0.80 Item: Polk Audio CS10 Center Channel Speaker (...
# 63: Guess: $322.22 Truth: $364.41 Error: $42.19 SLE: 0.02 Item: Wilwood Engineering 14011291R Brake Cali...
# 64: Guess: $262.47 Truth: $126.65 Error: $135.82 SLE: 0.53 Item: Progress Lighting P4632-09 Inspire Chand...
# 65: Guess: $579.99 Truth: $778.95 Error: $198.96 SLE: 0.09 Item: UWS EC10783 69-Inch Matte Black Heavy-Wa...
# 66: Guess: $127.99 Truth: $206.66 Error: $78.67 SLE: 0.23 Item: Dell Latitude E5440 14in Business Laptop...
# 67: Guess: $69.99 Truth: $35.52 Error: $34.47 SLE: 0.44 Item: Manhattan Toy Beats to Go Wooden Toddler...
# 68: Guess: $219.65 Truth: $149.00 Error: $70.65 SLE: 0.15 Item: Beachtek DXA-MICRO PRO Audio Adapter
# 69: Guess: $221.65 Truth: $251.98 Error: $30.33 SLE: 0.02 Item: Brand New 18" x 8.5" Replacement Wheel f...
# 70: Guess: $47.22 Truth: $159.95 Error: $112.73 SLE: 1.45 Item: Diamond Select Toys Marvel Premier Colle...
# 71: Guess: $22.22 Truth: $40.41 Error: $18.19 SLE: 0.33 Item: NCY Leather Grip Set (Brown); Universal ...
# 72: Guess: $221.65 Truth: $362.41 Error: $140.76 SLE: 0.24 Item: AC Compressor & A/C Clutch For Hyundai A...
# 73: Guess: $277.65 Truth: $344.00 Error: $66.35 SLE: 0.05 Item: House Of Troy PIN475-AB Pinnacle Collect...
# 74: Guess: $43.66 Truth: $24.99 Error: $18.67 SLE: 0.29 Item: Green Toys Block Set - 18 Piece Pretend ...
# 75: Guess: $22.99 Truth: $175.99 Error: $153.00 SLE: 3.99 Item: Wire Tracker, Telephone Cable Locator 12...
# 76: Guess: $127.22 Truth: $132.86 Error: $5.64 SLE: 0.00 Item: Office Dimensions 18in. 2 Drawer Metal S...
# 77: Guess: $726.65 Truth: $422.99 Error: $303.66 SLE: 0.29 Item: Rockland VMI14 12,000 Pound 12 Volt DC E...
# 78: Guess: $322.22 Truth: $145.80 Error: $176.42 SLE: 0.62 Item: Detroit Axle - Front Brake Kit for Toyot...
# 79: Guess: $221.65 Truth: $156.99 Error: $64.66 SLE: 0.12 Item: CURT 13382 Class 3 Trailer Hitch, 2-Inch...
# 80: Guess: $219.00 Truth: $251.99 Error: $32.99 SLE: 0.02 Item: Lucida LG-510 Student Classical Guitar, ...
# 81: Guess: $47.95 Truth: $940.33 Error: $892.38 SLE: 8.74 Item: Longacre 52-79800 Aluminum Turn Plates
# 82: Guess: $47.95 Truth: $52.95 Error: $5.00 SLE: 0.01 Item: Curb N Sign Address Numbers for House - ...
# 83: Guess: $127.22 Truth: $220.22 Error: $93.00 SLE: 0.30 Item: SanDisk Cruzer Blade 8GB USB 2.0/3.0 Fla...
# 84: Guess: $594.65 Truth: $441.03 Error: $153.62 SLE: 0.09 Item: TOYO Open Country MT Performance Radial ...
# 85: Guess: $174.99 Truth: $169.49 Error: $5.50 SLE: 0.00 Item: Serena D'italia Tiffany-Style Mini Drago...
# 86: Guess: $0.47 Truth: $1.99 Error: $1.52 SLE: 0.50 Item: Pokemon - Purrloin (66) - Black and Whit...
# 87: Guess: $109.99 Truth: $99.00 Error: $10.99 SLE: 0.01 Item: Luckmart Welding Cart Plasma Cutter MIG ...
# 88: Guess: $47.95 Truth: $256.95 Error: $209.00 SLE: 2.76 Item: Studio M Peace and Harmony Art Pole Comm...
# 89: Guess: $66.47 Truth: $31.00 Error: $35.47 SLE: 0.56 Item: CMS 16GB (2X8GB) DDR3 12800 1600MHz Non ...
# 90: Guess: $393.69 Truth: $569.84 Error: $176.15 SLE: 0.14 Item: Dell Latitude 7212 Rugged Extreme Tablet...
# 91: Guess: $262.47 Truth: $177.99 Error: $84.48 SLE: 0.15 Item: Covermates Contour Fit Car Cover - Light...
# 92: Guess: $572.47 Truth: $997.99 Error: $425.52 SLE: 0.31 Item: Westin 57-4025 Black HDX Grille Guard fi...
# 93: Guess: $219.00 Truth: $219.00 Error: $0.00 SLE: 0.00 Item: Juicebox Gold Mount Battery & Charger (1...
# 94: Guess: $221.65 Truth: $225.55 Error: $3.90 SLE: 0.00 Item: hansgrohe Talis S Modern Premium Easy Cl...
# 95: Guess: $579.99 Truth: $495.95 Error: $84.04 SLE: 0.02 Item: G-Technology G-SPEED eS PRO High-Perform...
# 96: Guess: $674.99 Truth: $942.37 Error: $267.38 SLE: 0.11 Item: DreamLine SHDR-1960723L-01 Shower Door, ...
# 97: Guess: $5.65 Truth: $1.90 Error: $3.75 SLE: 0.69 Item: Jay Graphics 5.56 Oval Euro Vinyl Bumper...
# 98: Guess: $221.65 Truth: $284.34 Error: $62.69 SLE: 0.06 Item: Pelican Protector 1750 Long Case - Multi...
# 99: Guess: $127.22 Truth: $171.90 Error: $44.68 SLE: 0.09 Item: Brock Replacement Driver and Passenger H...
# 100: Guess: $179.99 Truth: $144.99 Error: $35.00 SLE: 0.05 Item: New RODWIL Electric Tankless Water Heate...
# 101: Guess: $799.95 Truth: $470.47 Error: $329.48 SLE: 0.28 Item: StarDot NetCamLIVE2 YouTube Live Stream ...
# 102: Guess: $66.47 Truth: $66.95 Error: $0.48 SLE: 0.00 Item: (4-Pack, B+C+M+Y) Compatible Toner Cartr...
# 103: Guess: $154.65 Truth: $116.97 Error: $37.68 SLE: 0.08 Item: RAREELECTRICAL NEW RIGHT OUTER TAIL LIGH...
# 104: Guess: $276.10 Truth: $172.14 Error: $103.96 SLE: 0.22 Item: Fit System 62135G Passenger Side Towing ...
# 105: Guess: $594.00 Truth: $392.74 Error: $201.26 SLE: 0.17 Item: Black Horse Black Aluminum Exceed Runnin...
# 106: Guess: $10.99 Truth: $16.99 Error: $6.00 SLE: 0.16 Item: Universal Replacement Remote Control Fit...
# 107: Guess: $0.65 Truth: $0.66 Error: $0.01 SLE: 0.00 Item: Goblin Gaveleer
# 108: Guess: $239.99 Truth: $349.98 Error: $109.99 SLE: 0.14 Item: Ibanez GA34STCE-NT GIO Series Classical ...
# 109: Guess: $726.65 Truth: $370.71 Error: $355.94 SLE: 0.45 Item: Set 2 Heavy Duty 12-16.5 12x16.5 12 Ply ...
# 110: Guess: $65.69 Truth: $65.99 Error: $0.30 SLE: 0.00 Item: Pyramex RWB4610M RWB46 Series- Pants H-V...
# 111: Guess: $127.99 Truth: $229.99 Error: $102.00 SLE: 0.34 Item: AGLUCKY Nugget Ice Maker Countertop, Por...
# 112: Guess: $8.99 Truth: $8.99 Error: $0.00 SLE: 0.00 Item: Screen Tempered Glass for Galaxy LG K31,...
# 113: Guess: $224.98 Truth: $199.00 Error: $25.98 SLE: 0.01 Item: (2) Chauvet DJ SlimPar 56 LED DMX Slim P...
# 114: Guess: $66.47 Truth: $109.99 Error: $43.52 SLE: 0.25 Item: Savonnerie Black Pendant Lighting for Ki...
# 115: Guess: $594.65 Truth: $570.42 Error: $24.23 SLE: 0.00 Item: R1 Concepts Front Rear Brakes and Rotors...
# 116: Guess: $600.97 Truth: $279.99 Error: $320.98 SLE: 0.58 Item: Camplux 2.64 GPM Tankless , Outdoor Port...
# 117: Guess: $66.47 Truth: $31.43 Error: $35.04 SLE: 0.54 Item: NANIWA Japanese Whetstone, Lobster Carbo...
# 118: Guess: $11.99 Truth: $31.99 Error: $20.00 SLE: 0.87 Item: Extech 42299 3.6V Lithium Batteries
# 119: Guess: $19.99 Truth: $15.99 Error: $4.00 SLE: 0.04 Item: 20 Watts iPad Charger USB C Fast Chargin...
# 120: Guess: $154.98 Truth: $45.54 Error: $109.44 SLE: 1.46 Item: Yamaguchi 23-535 - 2016 piece Kintai Bri...
# 121: Guess: $393.69 Truth: $113.99 Error: $279.70 SLE: 1.52 Item: LEGO Marvel Super Heroes Avengers: Infin...
# 122: Guess: $726.65 Truth: $516.99 Error: $209.66 SLE: 0.12 Item: Patriot Exhaust H8013-1 1-7/8" Clippster...
# 123: Guess: $174.99 Truth: $196.99 Error: $22.00 SLE: 0.01 Item: Fitrite Autopart New Front Left Driver S...
# 124: Guess: $47.99 Truth: $46.54 Error: $1.45 SLE: 0.00 Item: Qiilu Heavy Duty 1/2" Air Impact Wrench ...
# 125: Guess: $262.47 Truth: $356.99 Error: $94.52 SLE: 0.09 Item: Covercraft Carhartt SeatSaver Front Row ...
# 126: Guess: $277.65 Truth: $319.95 Error: $42.30 SLE: 0.02 Item: Sennheiser SD Pro 2 (506008) - Double-Si...
# 127: Guess: $179.88 Truth: $95.95 Error: $83.93 SLE: 0.39 Item: Manfrotto MB PL-AH-18 Holster (Black)
# 128: Guess: $109.99 Truth: $190.99 Error: $81.00 SLE: 0.30 Item: AmScope SE305R-P-LED-PS36A 10X-30X LED C...
# 129: Guess: $127.22 Truth: $257.95 Error: $130.73 SLE: 0.49 Item: Front Left Driver Side Window Regulator ...
# 130: Guess: $221.65 Truth: $63.35 Error: $158.30 SLE: 1.54 Item: Dynamic Friction Company True Balanced B...
# 131: Guess: $65.65 Truth: $47.99 Error: $17.66 SLE: 0.09 Item: AJP Distributors For 1992 1993 1994 1995...
# 132: Guess: $594.99 Truth: $226.99 Error: $368.00 SLE: 0.92 Item: RC4WD BigDog Dual Axle Scale Car/Truck T...
# 133: Guess: $274.00 Truth: $359.95 Error: $85.95 SLE: 0.07 Item: Unknown Stage 2 Clutch Kit - Low Altitud...
# 134: Guess: $65.65 Truth: $77.90 Error: $12.25 SLE: 0.03 Item: NGK/NTK Auto Trans Speed Sensor AU0128 (...
# 135: Guess: $262.47 Truth: $172.77 Error: $89.70 SLE: 0.17 Item: Pro Comp Alloys Series 89 Wheel with Pol...
# 136: Guess: $127.22 Truth: $316.45 Error: $189.23 SLE: 0.82 Item: Detroit Axle - Front Rear Strut & Coil S...
# 137: Guess: $154.65 Truth: $88.00 Error: $66.65 SLE: 0.31 Item: TYC 700248 Compatible with MERCEDES-Benz...
# 138: Guess: $127.99 Truth: $226.63 Error: $98.64 SLE: 0.32 Item: Dell Latitude E6520 Intel i7-2720QM 2.20...
# 139: Guess: $47.22 Truth: $31.12 Error: $16.10 SLE: 0.17 Item: Industrial Performance 60G16.5/CL 130V, ...
# 140: Guess: $154.65 Truth: $196.00 Error: $41.35 SLE: 0.06 Item: Flash Furniture 4 Pk. HERCULES Series 88...
# 141: Guess: $174.99 Truth: $77.99 Error: $97.00 SLE: 0.64 Item: KOKOMANDY Cute 24inch Realistic Reborn B...
# 142: Guess: $127.22 Truth: $116.00 Error: $11.22 SLE: 0.01 Item: Kinesis C850 X-Large Holster Case (for A...
# 143: Guess: $100.69 Truth: $112.99 Error: $12.30 SLE: 0.01 Item: DNA MOTORING HL-OH-CV974P-BK-AM Black Am...
# 144: Guess: $49.95 Truth: $26.99 Error: $22.96 SLE: 0.36 Item: Zuma Filters GE GTS22KHP Compatible Refr...
# 145: Guess: $47.22 Truth: $145.70 Error: $98.48 SLE: 1.24 Item: HCO Outdoor Products IR Flash Camera wit...
# 146: Guess: $66.47 Truth: $171.09 Error: $104.62 SLE: 0.88 Item: Garage-Pro Tailgate SET Compatible with ...
# 147: Guess: $127.22 Truth: $167.99 Error: $40.77 SLE: 0.08 Item: A-Premium Disc Brake Caliper Assembly wi...
# 148: Guess: $65.65 Truth: $27.57 Error: $38.08 SLE: 0.72 Item: Melissa & Doug Emergency Vehicle Wooden ...
# 149: Guess: $65.65 Truth: $122.29 Error: $56.64 SLE: 0.38 Item: Golan Products 75-516D-BLK 3/8 NPT Petco...
# 150: Guess: $65.65 Truth: $32.99 Error: $32.66 SLE: 0.45 Item: BLU Tank Mega T570 2.4" GSM Unlocked Cel...
# 151: Guess: $66.47 Truth: $71.00 Error: $4.53 SLE: 0.00 Item: Festool 497168 Granat P100 Grit 5-Inch (...
# 152: Guess: $143.65 Truth: $112.99 Error: $30.66 SLE: 0.06 Item: LCDOLED Replacement for HP Pavilion x360...
# 153: Guess: $127.22 Truth: $141.70 Error: $14.48 SLE: 0.01 Item: Elk 43017/1 Farmstead 1-Light Outdoor Pe...
# 154: Guess: $367.99 Truth: $398.99 Error: $31.00 SLE: 0.01 Item: SAREMAS Foot Step Bars for Hyundai Palis...
# 155: Guess: $972.66 Truth: $449.00 Error: $523.66 SLE: 0.60 Item: Gretsch G9210 Square Neck Boxcar Mahogan...
# 156: Guess: $109.00 Truth: $189.00 Error: $80.00 SLE: 0.30 Item: EXO Scout || Drone with Camera for Adult...
# 157: Guess: $262.47 Truth: $121.29 Error: $141.18 SLE: 0.59 Item: DNA MOTORING CBE-HA90-BT Stainless Steel...
# 158: Guess: $127.22 Truth: $203.53 Error: $76.31 SLE: 0.22 Item: R&L Racing Heavy Duty Roll-Up Soft Tonne...
# 159: Guess: $393.69 Truth: $349.99 Error: $43.70 SLE: 0.01 Item: Garmin 010-02258-10 GPSMAP 64sx, Handhel...
# 160: Guess: $22.99 Truth: $34.28 Error: $11.29 SLE: 0.15 Item: INTEL Xeon 3 Ghz Quad Core E5450 LGA771 ...
# 161: Guess: $219.00 Truth: $384.99 Error: $165.99 SLE: 0.32 Item: GAOMON PD2200 Pen Display & 20 Pen Nibs ...
# 162: Guess: $393.69 Truth: $211.00 Error: $182.69 SLE: 0.39 Item: VXMOTOR for 97-03 Ford F150/F250 Lightdu...
# 163: Guess: $143.65 Truth: $129.00 Error: $14.65 SLE: 0.01 Item: Swing Kingdom Tic Tac Toe Panel
# 164: Guess: $202.65 Truth: $110.91 Error: $91.74 SLE: 0.36 Item: Timken HA590070 Axle Bearing and Hub Ass...
# 165: Guess: $128.66 Truth: $81.20 Error: $47.46 SLE: 0.21 Item: Toto TSU03W.14R Bathroom-Hardware, Other
# 166: Guess: $139.98 Truth: $457.08 Error: $317.10 SLE: 1.39 Item: Vixen Air 1/2" NPT Air Ride Suspension H...
# 167: Guess: $156.66 Truth: $49.06 Error: $107.60 SLE: 1.32 Item: Precisionaire Furnace Air Filter 24 " X ...
# 168: Guess: $66.47 Truth: $81.40 Error: $14.93 SLE: 0.04 Item: Compatible to Guardian Gorilla Driveway ...
# 169: Guess: $262.47 Truth: $278.39 Error: $15.92 SLE: 0.00 Item: Mickey Thompson ET Street S/S Racing Rad...
# 170: Guess: $322.22 Truth: $364.50 Error: $42.28 SLE: 0.02 Item: Pirelli 275/40R20 106W XL RFT P0 PZ4-LUX...
# 171: Guess: $174.99 Truth: $378.99 Error: $204.00 SLE: 0.59 Item: Torklift C3212 Rear Tie Down
# 172: Guess: $490.00 Truth: $164.79 Error: $325.21 SLE: 1.18 Item: Universal Air Conditioner KT 4383 A/C Co...
# 173: Guess: $66.47 Truth: $56.60 Error: $9.87 SLE: 0.03 Item: Custom Embosser Seal; Personalized Monog...
# 174: Guess: $221.65 Truth: $307.95 Error: $86.30 SLE: 0.11 Item: 3M Protecta 3100414 Self Retracting Life...
# 175: Guess: $209.00 Truth: $37.89 Error: $171.11 SLE: 2.84 Item: SPEEDWOLF 10M / 33FT 12 Fibers Type B OM...
# 176: Guess: $128.66 Truth: $52.99 Error: $75.67 SLE: 0.77 Item: FRANSITON Waterfall Faucet Bathroom Fauc...
# 177: Guess: $649.98 Truth: $498.00 Error: $151.98 SLE: 0.07 Item: Olympus PEN E-PL9 Body Only with 3-Inch ...
# 178: Guess: $47.22 Truth: $54.28 Error: $7.06 SLE: 0.02 Item: Talicor Games I Love Lucy Board Game
# 179: Guess: $268.47 Truth: $350.00 Error: $81.53 SLE: 0.07 Item: Eibach Pro-Kit Performance Springs E10-6...
# 180: Guess: $390.22 Truth: $299.95 Error: $90.27 SLE: 0.07 Item: LEGO DC Batman 1989 Batwing 76161 Displa...
# 181: Guess: $174.00 Truth: $94.99 Error: $79.01 SLE: 0.36 Item: Makita XFD14Z 18V LXT® Lithium-Ion Brush...
# 182: Guess: $349.00 Truth: $379.00 Error: $30.00 SLE: 0.01 Item: Polk Vanishing Series 265-LS In-Wall 3-W...
# 183: Guess: $221.65 Truth: $299.95 Error: $78.30 SLE: 0.09 Item: Spec-D Tuning LED Projector Headlights G...
# 184: Guess: $14.98 Truth: $24.99 Error: $10.01 SLE: 0.24 Item: ArtCreativity Southern Stingray Puppet, ...
# 185: Guess: $65.65 Truth: $40.78 Error: $24.87 SLE: 0.22 Item: ACDelco Professional 45A1109 Inner Steer...
# 186: Guess: $47.99 Truth: $327.90 Error: $279.91 SLE: 3.63 Item: SAUTVS LED Headlight Assembly for Slings...
# 187: Guess: $7.47 Truth: $10.99 Error: $3.52 SLE: 0.12 Item: WINNIE THE POOH Disney Hide and Seek! Co...
# 188: Guess: $14.65 Truth: $14.99 Error: $0.34 SLE: 0.00 Item: Mama Bear Transgender Mom Trans Pride Gi...
# 189: Guess: $154.65 Truth: $84.80 Error: $69.85 SLE: 0.35 Item: Monroe Shocks & Struts OESpectrum 72456 ...
# 190: Guess: $174.99 Truth: $110.99 Error: $64.00 SLE: 0.20 Item: Lexmark Photoconductor Kit
# 191: Guess: $127.22 Truth: $123.51 Error: $3.71 SLE: 0.00 Item: Dry Erase Surface with Adhesive Backing,...
# 192: Guess: $393.69 Truth: $557.38 Error: $163.69 SLE: 0.12 Item: Tascam DP-24SD 24-Track Digital Portastu...
# 193: Guess: $47.22 Truth: $96.00 Error: $48.78 SLE: 0.49 Item: HEWC9384A - HP C9384A HP 72 Printhead
# 194: Guess: $174.99 Truth: $153.70 Error: $21.29 SLE: 0.02 Item: D.I.D (DKS-001) 525VX Chain and 16/45T S...
# 195: Guess: $139.98 Truth: $198.85 Error: $58.87 SLE: 0.12 Item: B&K Precision 1550 Switching DC Power Su...
# 196: Guess: $726.65 Truth: $430.44 Error: $296.21 SLE: 0.27 Item: PHYNEDI 1:1000 World Trade Center (1973-...
# 197: Guess: $221.65 Truth: $45.79 Error: $175.86 SLE: 2.43 Item: Yana Shiki USA FFK-210-BK Front Fender-K...
# 198: Guess: $127.22 Truth: $249.00 Error: $121.78 SLE: 0.45 Item: Interlogix NX-1820E NetworX Touch Screen...
# 199: Guess: $65.65 Truth: $43.45 Error: $22.20 SLE: 0.16 Item: Astrozap 8 ETX LS Flexi-Shield® Flexible...
# 200: Guess: $66.47 Truth: $181.33 Error: $114.86 SLE: 0.99 Item: Amprobe TIC 410A Hot Stick Attachment
# 201: Guess: $8.69 Truth: $5.99 Error: $2.70 SLE: 0.11 Item: iPhone 7/8 Plus Full Cover glass Screen ...
# 202: Guess: $1.60 Truth: $29.98 Error: $28.38 SLE: 6.14 Item: Comic Book Toploader Colored Border Edge...
# 203: Guess: $726.65 Truth: $899.00 Error: $172.35 SLE: 0.05 Item: Dell XPS X8700-1572BLK Desktop ( Intel C...
# 204: Guess: $349.95 Truth: $399.99 Error: $50.04 SLE: 0.02 Item: Franklin Iron Works Sperry Industrial Br...
# 205: Guess: $18.99 Truth: $4.99 Error: $14.00 SLE: 1.45 Item: YANWEI Cat8 Ethernet Cable,3ft 26AWG Hea...
# 206: Guess: $127.22 Truth: $261.41 Error: $134.19 SLE: 0.51 Item: Moen 8346 Commercial Posi-Temp Pressure ...
# 207: Guess: $322.22 Truth: $136.99 Error: $185.23 SLE: 0.72 Item: Power Stop K681 Front Z23 Carbon Fiber B...
# 208: Guess: $65.69 Truth: $78.99 Error: $13.30 SLE: 0.03 Item: TRIBLE SIX 4Pcs 4x137mm 2'' ATV Wheel Sp...
# 209: Guess: $164.50 Truth: $444.99 Error: $280.49 SLE: 0.98 Item: NanoBeam AC NBE-5AC-Gen2-US 4 Units 5GHz...
# 210: Guess: $390.22 Truth: $411.94 Error: $21.72 SLE: 0.00 Item: WULF 4" Front 2" Rear Leveling Lift Kit ...
# 211: Guess: $109.00 Truth: $147.54 Error: $38.54 SLE: 0.09 Item: BOANN BNYKF-C21S Helena 14.4-Inch 304 St...
# 212: Guess: $154.98 Truth: $244.99 Error: $90.01 SLE: 0.21 Item: YU-GI-OH! Ignition Assault Booster Box
# 213: Guess: $139.65 Truth: $86.49 Error: $53.16 SLE: 0.23 Item: Lascar EL-USB-RT Temperature Humidity an...
# 214: Guess: $147.77 Truth: $297.95 Error: $150.18 SLE: 0.49 Item: Dell Latitude D620 Renewed Notebook PC
# 215: Guess: $393.69 Truth: $399.99 Error: $6.30 SLE: 0.00 Item: acer Aspire 5 Laptop, AMD Ryzen 3 5300U ...
# 216: Guess: $490.00 Truth: $599.00 Error: $109.00 SLE: 0.04 Item: Elk 31080/6RC-GRN 30 by 6-Inch Viva 6-Li...
# 217: Guess: $196.99 Truth: $105.82 Error: $91.17 SLE: 0.38 Item: IAP Performance AC119022 VW Beetle Chrom...
# 218: Guess: $1,127.00 Truth: $689.00 Error: $438.00 SLE: 0.24 Item: Danby Designer 20-In. Electric Range wit...
# 219: Guess: $174.99 Truth: $404.99 Error: $230.00 SLE: 0.70 Item: FixtureDisplays® Metal Truss Podium Doub...
# 220: Guess: $277.65 Truth: $207.76 Error: $69.89 SLE: 0.08 Item: ACDelco 13597235 GM Original Equipment A...
# 221: Guess: $276.10 Truth: $171.82 Error: $104.28 SLE: 0.22 Item: EBC S1KF1135 Stage-1 Premium Street Brak...
# 222: Guess: $359.95 Truth: $293.24 Error: $66.71 SLE: 0.04 Item: FXR Men's Boost FX Jacket (Black/Orange/...
# 223: Guess: $559.95 Truth: $374.95 Error: $185.00 SLE: 0.16 Item: SuperATV Scratch Resistant 3-in-1 Flip W...
# 224: Guess: $139.98 Truth: $112.00 Error: $27.98 SLE: 0.05 Item: Handmade World 16 Inch Buffalo Leather M...
# 225: Guess: $57.65 Truth: $42.99 Error: $14.66 SLE: 0.08 Item: Tic Tac Tiles 12"x12" 12-Sheet Peel and ...
# 226: Guess: $47.99 Truth: $117.29 Error: $69.30 SLE: 0.78 Item: MELPO LED Flood Light Outdoor 800W Equiv...
# 227: Guess: $143.65 Truth: $118.80 Error: $24.85 SLE: 0.04 Item: Leviton OSC15-RIW LV PIR CEILING OCC SNS...
# 228: Guess: $322.22 Truth: $147.35 Error: $174.87 SLE: 0.61 Item: Fortune Tormenta A/T FSR308 All-Terrain ...
# 229: Guess: $139.98 Truth: $119.99 Error: $19.99 SLE: 0.02 Item: Security Smart Deadbolt, Hornbill Keyles...
# 230: Guess: $262.47 Truth: $369.98 Error: $107.51 SLE: 0.12 Item: Whitehall™ Personalized Whitehall Capito...
# 231: Guess: $453.65 Truth: $315.55 Error: $138.10 SLE: 0.13 Item: Pro Circuit Works Pipe PY05250 for 02-19...
# 232: Guess: $219.99 Truth: $190.99 Error: $29.00 SLE: 0.02 Item: HYANKA 15 "1200W Professional DJ Speaker...
# 233: Guess: $128.66 Truth: $154.85 Error: $26.19 SLE: 0.03 Item: Abra Lighting 30060FM-BZ Lighting Fixtur...
# 234: Guess: $322.22 Truth: $349.99 Error: $27.77 SLE: 0.01 Item: AIRAID Cold Air Intake System by K&N: In...
# 235: Guess: $139.98 Truth: $249.99 Error: $110.01 SLE: 0.33 Item: Bostingner Shower Faucets Sets Complete,...
# 236: Guess: $139.98 Truth: $42.99 Error: $96.99 SLE: 1.36 Item: Electronic Descaler Water Conditioner Ha...
# 237: Guess: $14.65 Truth: $18.02 Error: $3.37 SLE: 0.04 Item: 3dRose lsp_32336_2 Double Toggle Switch ...
# 238: Guess: $453.65 Truth: $425.00 Error: $28.65 SLE: 0.00 Item: Fleck 2510 Timer Mechanical Filter Contr...
# 239: Guess: $219.98 Truth: $249.99 Error: $30.01 SLE: 0.02 Item: Haloview MC7108 Wireless RV Backup Camer...
# 240: Guess: $47.22 Truth: $137.95 Error: $90.73 SLE: 1.12 Item: Supreme Suspensions - 2.5" Front + 1" Re...
# 241: Guess: $277.65 Truth: $414.99 Error: $137.34 SLE: 0.16 Item: Corsa 14333 Tip Kit (Ford Mustang GT)
# 242: Guess: $49.90 Truth: $168.00 Error: $118.10 SLE: 1.44 Item: Mcoplus BG-550D Vertical Battery Grip as...
# 243: Guess: $219.98 Truth: $199.99 Error: $19.99 SLE: 0.01 Item: ATA HOBBY Radiolink A560 RC Airplane Rea...
# 244: Guess: $221.65 Truth: $126.99 Error: $94.66 SLE: 0.31 Item: Roof Racks Cross Bars Fit for Infiniti Q...
# 245: Guess: $22.22 Truth: $5.59 Error: $16.63 SLE: 1.59 Item: StarTech.com Slimline VGA HD15 Gender Ch...
# 246: Guess: $390.22 Truth: $193.06 Error: $197.16 SLE: 0.49 Item: Celestron - PowerSeeker 127EQ Telescope ...
# 247: Guess: $146.99 Truth: $249.99 Error: $103.00 SLE: 0.28 Item: NHOPEEW 10.1inch Android Car Radio Carpl...
# 248: Guess: $262.47 Truth: $63.89 Error: $198.58 SLE: 1.96 Item: Dumas Products Inc. P-38 F/M Lightning 3...
# 249: Guess: $34.98 Truth: $114.98 Error: $80.00 SLE: 1.37 Item: MotorDog69 Indian Gas Cap Coin Mount Set...
# 250: Guess: $726.65 Truth: $926.00 Error: $199.35 SLE: 0.06 Item: Elite Screens Edge Free Ambient Light Re...
